# %%
from google.colab import files
files.upload()

# %%
import pandas as pd
import datetime
df = pd.read_csv("Weather_Data.csv", parse_dates = ['Timestamp'], index_col = ['Timestamp'])
df.head()
# Out:
#                      Wind_Speed  Weather_Temperature_Celsius  \
# Timestamp
# 2016-04-01 00:00:00    0.736957                    15.695308
# 2016-04-01 01:00:00    1.116721                    15.458908
# 2016-04-01 02:00:00    0.998921                    15.686191
# 2016-04-01 03:00:00    1.076415                    14.938666
# 2016-04-01 04:00:00    1.448044                    13.401448
#
#                      Weather_Relative_Humidity  Global_Horizontal_Radiation  \
# Timestamp
# 2016-04-01 00:00:00                  40.470138                     2.656972
# 2016-04-01 01:00:00                  38.914876                     2.409956
# 2016-04-01 02:00:00                  38.183398                     2.349933
# 2016-04-01 03:00:00                  42.768116                     3.003918
# 2016-04-01 04:00:00                  51.339947                     3.034377
#
#                      Diffuse_Horizontal_Radiation  Wind_Direction  \
# Timestamp
# 2016-04-01 00:00:00                      1.036526      246.619743
# 2016-04-01 01:00:00                      0.803828       54.343306
# 2016-04-01 02:00:00                      0.776835       68.148311
# 2016-04-01 03:00:00                      1.336927      168.825974
# 2016-04-01 04:00:00                      1.368935      228.932444
#
#                      Weather_Daily_Rainfall  Radiation_Global_Tilted  \
# Timestamp
# 2016-04-01 00:00:00                     0.0                 3.082348
# 2016-04-01 01:00:00                     0.0                 2.691869
# 2016-04-01 02:00:00                     0.0                 2.676784
# 2016-04-01 03:00:00                     0.0                 3.319331
# 2016-04-01 04:00:00                     0.0                 3.422762
#
#                      Radiation_Diffuse_Tilted
# Timestamp
# 2016-04-01 00:00:00                  1.688183
# 2016-04-01 01:00:00                  1.369937
# 2016-04-01 02:00:00                  1.350582
# 2016-04-01 03:00:00                  1.908877
# 2016-04-01 04:00:00                  2.012935

# %%
import pandas as pd

df1 = pd.read_csv('Weather_Data.csv')  # Read the existing CSV file into a DataFrame
df1 = df1[:-9]

# Read the new CSV file into a DataFrame
df2 = pd.read_csv('Combined_DHASC_power.csv')

# Concatenate the new data with the existing DataFrame horizontally (by columns)
df = pd.concat([df1, df2], axis=1)

df.isnull().sum()
# Out:
# Timestamp                               0
# Wind_Speed                          55393
# Weather_Temperature_Celsius             9
# Weather_Relative_Humidity               9
# Global_Horizontal_Radiation             9
# Diffuse_Horizontal_Radiation            9
# Wind_Direction                          9
# Weather_Daily_Rainfall                  9
# Radiation_Global_Tilted              5496
# Radiation_Diffuse_Tilted             5496
# Timestamp                               0
# Active_Energy_Delivered_Received        0
# Current_Phase_Average                   1
# Active_Power                            0
# Power_Factor_Signed                     0
# Average_Voltage_Line_to_Neutral         1
# Frequency                               1
# THD_Voltage_Average                     1
# dtype: int64

# %%
import datetime
df.to_csv('combined_file.csv', index=False)
df = pd.read_csv("combined_file.csv", parse_dates = ['Timestamp'], index_col = ['Timestamp'])
df.shape

# %%
df = df.drop('Active_Energy_Delivered_Received', axis=1)
df = df.drop('Current_Phase_Average', axis=1)
df = df.drop('Power_Factor_Signed', axis=1)
df = df.drop('Average_Voltage_Line_to_Neutral', axis=1)
df = df.drop('THD_Voltage_Average', axis=1)
df = df.drop('Frequency', axis=1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

plt.figure(figsize=(18,18))
cor1 = df.corr()
sns.heatmap(cor1, annot=True, cmap="viridis",annot_kws={"size":8})
plt.show()

# %%
df = df.copy()
df['date'] = df.index
df['Date'] = df['date'].dt.date
df['hour'] = df['date'].dt.hour
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year
df.head()
# Out:
#                      Wind_Speed  Weather_Temperature_Celsius  \
# Timestamp
# 2016-04-01 00:00:00    0.736957                    15.695308
# 2016-04-01 01:00:00    1.116721                    15.458908
# 2016-04-01 02:00:00    0.998921                    15.686191
# 2016-04-01 03:00:00    1.076415                    14.938666
# 2016-04-01 04:00:00    1.448044                    13.401448
#
#                      Weather_Relative_Humidity  Global_Horizontal_Radiation  \
# Timestamp
# 2016-04-01 00:00:00                  40.470138                     2.656972
# 2016-04-01 01:00:00                  38.914876                     2.409956
# 2016-04-01 02:00:00                  38.183398                     2.349933
# 2016-04-01 03:00:00                  42.768116                     3.003918
# 2016-04-01 04:00:00                  51.339947                     3.034377
#
#                      Diffuse_Horizontal_Radiation  Wind_Direction  \
# Timestamp
# 2016-04-01 00:00:00                      1.036526      246.619743
# 2016-04-01 01:00:00                      0.803828       54.343306
# 2016-04-01 02:00:00                      0.776835       68.148311
# 2016-04-01 03:00:00                      1.336927      168.825974
# 2016-04-01 04:00:00                      1.368935      228.932444
#
#                      Weather_Daily_Rainfall  Radiation_Global_Tilted  \
# Timestamp
# 2016-04-01 00:00:00                     0.0                 3.082348
# 2016-04-01 01:00:00                     0.0                 2.691869
# 2016-04-01 02:00:00                     0.0                 2.676784
# 2016-04-01 03:00:00                     0.0                 3.319331
# 2016-04-01 04:00:00                     0.0                 3.422762
#
#                      Radiation_Diffuse_Tilted                date        Date  \
# Timestamp
# 2016-04-01 00:00:00                  1.688183 2016-04-01 00:00:00  2016-04-01
# 2016-04-01 01:00:00                  1.369937 2016-04-01 01:00:00  2016-04-01
# 2016-04-01 02:00:00                  1.350582 2016-04-01 02:00:00  2016-04-01
# 2016-04-01 03:00:00                  1.908877 2016-04-01 03:00:00  2016-04-01
# 2016-04-01 04:00:00                  2.012935 2016-04-01 04:00:00  2016-04-01
#
#                      hour  month  year
# Timestamp
# 2016-04-01 00:00:00     0      4  2016
# 2016-04-01 01:00:00     1      4  2016
# 2016-04-01 02:00:00     2      4  2016
# 2016-04-01 03:00:00     3      4  2016
# 2016-04-01 04:00:00     4      4  2016

# %%
df.reset_index(inplace=True)
#df.to_csv("Weather_Data_new.csv", index=False)
df = df.drop('Timestamp', axis=1)
df = df.drop('Wind_Speed', axis=1)
df.head()
# Out:
#    Weather_Temperature_Celsius  Weather_Relative_Humidity  \
# 0                    15.695308                  40.470138
# 1                    15.458908                  38.914876
# 2                    15.686191                  38.183398
# 3                    14.938666                  42.768116
# 4                    13.401448                  51.339947
#
#    Global_Horizontal_Radiation  Diffuse_Horizontal_Radiation  Wind_Direction  \
# 0                     2.656972                      1.036526      246.619743
# 1                     2.409956                      0.803828       54.343306
# 2                     2.349933                      0.776835       68.148311
# 3                     3.003918                      1.336927      168.825974
# 4                     3.034377                      1.368935      228.932444
#
#    Weather_Daily_Rainfall  Radiation_Global_Tilted  Radiation_Diffuse_Tilted  \
# 0                     0.0                 3.082348                  1.688183
# 1                     0.0                 2.691869                  1.369937
# 2                     0.0                 2.676784                  1.350582
# 3                     0.0                 3.319331                  1.908877
# 4                     0.0                 3.422762                  2.012935
#
#                  date        Date  hour  month  year
# 0 2016-04-01 00:00:00  2016-04-01     0      4  2016
# 1 2016-04-01 01:00:00  2016-04-01     1      4  2016
# 2 2016-04-01 02:00:00  2016-04-01     2      4  2016
# 3 2016-04-01 03:00:00  2016-04-01     3      4  2016
# 4 2016-04-01 04:00:00  2016-04-01     4      4  2016

# %%
df.isnull().sum()
# Out:
# Weather_Temperature_Celsius        9
# Weather_Relative_Humidity          9
# Global_Horizontal_Radiation        9
# Diffuse_Horizontal_Radiation       9
# Wind_Direction                     9
# Weather_Daily_Rainfall             9
# Radiation_Global_Tilted         5496
# Radiation_Diffuse_Tilted        5496
# date                               0
# Date                               0
# hour                               0
# month                              0
# year                               0
# dtype: int64

# %%
test_data = df[df["Radiation_Global_Tilted"].isnull()]
test_data.shape


x_test = test_data[["Global_Horizontal_Radiation"]]
x_test.shape
# Out:
# (5496, 1)

# %%
test_data.head()
# Out:
#     Weather_Temperature_Celsius  Weather_Relative_Humidity  \
# 73                    14.947137                  36.891554
# 74                    14.157577                  41.880628
# 75                    13.462600                  45.648246
# 76                    12.623549                  48.682053
# 77                    12.252230                  50.790312
#
#     Global_Horizontal_Radiation  Diffuse_Horizontal_Radiation  Wind_Direction  \
# 73                     2.769133                      1.122296      243.446524
# 74                     2.890077                      1.223685      249.287980
# 75                     2.771298                      1.136136      238.922204
# 76                     2.890348                      1.239373       12.695471
# 77                     2.618698                      0.993133      258.034283
#
#     Weather_Daily_Rainfall  Radiation_Global_Tilted  Radiation_Diffuse_Tilted  \
# 73                     0.0                      NaN                       NaN
# 74                     0.0                      NaN                       NaN
# 75                     0.0                      NaN                       NaN
# 76                     0.0                      NaN                       NaN
# 77                     0.0                      NaN                       NaN
#
#                   date        Date  hour  month  year
# 73 2016-04-04 01:00:00  2016-04-04     1      4  2016
# 74 2016-04-04 02:00:00  2016-04-04     2      4  2016
# 75 2016-04-04 03:00:00  2016-04-04     3      4  2016
# 76 2016-04-04 04:00:00  2016-04-04     4      4  2016
# 77 2016-04-04 05:00:00  2016-04-04     5      4  2016

# %%
train_data = df.dropna(subset="Radiation_Global_Tilted")
train_data.shape
# Out:
# (54792, 13)

# %%
x_train = train_data[["Global_Horizontal_Radiation"]]
x_train = x_train.fillna(method='ffill')
x_train.shape
# Out:
# (54792, 1)

# %%
y_train = train_data["Radiation_Global_Tilted"]
y_train.shape
# Out:
# (54792,)

# %%
from sklearn.linear_model import LinearRegression
LR_model = LinearRegression()

# %%
LR_model.fit(x_train, y_train)

train_score = LR_model.score(x_train, y_train)

print(f"Model Score (R^2) on Training Data: {train_score}")
# Out:
# Model Score (R^2) on Training Data: 0.9654307029512679

# %%
import math
from sklearn.metrics import mean_absolute_error,mean_squared_error
y_train_pred = LR_model.predict(x_train)

mse = mean_squared_error(y_train, y_train_pred)
rmse = math.sqrt(mse)
print(f'Root Mean Squared Error: {rmse}')

mae_train = mean_absolute_error(y_train, y_train_pred)

print(f"Mean Absolute Error (MAE) on Training Data: {mae_train}")
# Out:
# Root Mean Squared Error: 71.01700106890598
# Mean Absolute Error (MAE) on Training Data: 38.89398370191839

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model
random_forest_model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
train_score_rf = random_forest_model.score(x_train, y_train)

print(f"Model Score (R^2) on Training Data: {train_score_rf}")
# Out:
# Model Score (R^2) on Training Data: 0.990369321179292

# %%
from sklearn.metrics import mean_absolute_error
y_train_pred = random_forest_model.predict(x_train)
mae_train = mean_absolute_error(y_train, y_train_pred)

mse = mean_squared_error(y_train, y_train_pred)
rmse = math.sqrt(mse)
print(f'Root Mean Squared Error: {rmse}')

print(f"Mean Absolute Error (MAE) on Training Data: {mae_train}")
# Out:
# Root Mean Squared Error: 37.48396333185384
# Mean Absolute Error (MAE) on Training Data: 15.038692927302424

# %%
y_pred = random_forest_model.predict(x_test)
y_pred.shape
# Out:
# (5496,)

# %%
test_data.loc[test_data.Radiation_Global_Tilted.isnull(), 'Radiation_Global_Tilted'] = y_pred
test_data.head()
# Out:
#     Weather_Temperature_Celsius  Weather_Relative_Humidity  \
# 73                    14.947137                  36.891554
# 74                    14.157577                  41.880628
# 75                    13.462600                  45.648246
# 76                    12.623549                  48.682053
# 77                    12.252230                  50.790312
#
#     Global_Horizontal_Radiation  Diffuse_Horizontal_Radiation  Wind_Direction  \
# 73                     2.769133                      1.122296      243.446524
# 74                     2.890077                      1.223685      249.287980
# 75                     2.771298                      1.136136      238.922204
# 76                     2.890348                      1.239373       12.695471
# 77                     2.618698                      0.993133      258.034283
#
#     Weather_Daily_Rainfall  Radiation_Global_Tilted  Radiation_Diffuse_Tilted  \
# 73                     0.0                 2.229095                       NaN
# 74                     0.0                 1.707711                       NaN
# 75                     0.0                 2.506192                       NaN
# 76                     0.0                 2.016426                       NaN
# 77                     0.0                 2.618487                       NaN
#
#                   date        Date  hour  month  year
# 73 2016-04-04 01:00:00  2016-04-04     1      4  2016
# 74 2016-04-04 02:00:00  2016-04-04     2      4  2016
# 75 2016-04-04 03:00:00  2016-04-04     3      4  2016
# 76 2016-04-04 04:00:00  2016-04-04     4      4  2016
# 77 2016-04-04 05:00:00  2016-04-04     5      4  2016

# %%
df = pd.concat([train_data,test_data])
df.sort_index(inplace=True)
df.head()
# Out:
#    Weather_Temperature_Celsius  Weather_Relative_Humidity  \
# 0                    15.695308                  40.470138
# 1                    15.458908                  38.914876
# 2                    15.686191                  38.183398
# 3                    14.938666                  42.768116
# 4                    13.401448                  51.339947
#
#    Global_Horizontal_Radiation  Diffuse_Horizontal_Radiation  Wind_Direction  \
# 0                     2.656972                      1.036526      246.619743
# 1                     2.409956                      0.803828       54.343306
# 2                     2.349933                      0.776835       68.148311
# 3                     3.003918                      1.336927      168.825974
# 4                     3.034377                      1.368935      228.932444
#
#    Weather_Daily_Rainfall  Radiation_Global_Tilted  Radiation_Diffuse_Tilted  \
# 0                     0.0                 3.082348                  1.688183
# 1                     0.0                 2.691869                  1.369937
# 2                     0.0                 2.676784                  1.350582
# 3                     0.0                 3.319331                  1.908877
# 4                     0.0                 3.422762                  2.012935
#
#                  date        Date  hour  month  year
# 0 2016-04-01 00:00:00  2016-04-01     0      4  2016
# 1 2016-04-01 01:00:00  2016-04-01     1      4  2016
# 2 2016-04-01 02:00:00  2016-04-01     2      4  2016
# 3 2016-04-01 03:00:00  2016-04-01     3      4  2016
# 4 2016-04-01 04:00:00  2016-04-01     4      4  2016

# %%
test_data = df[df["Radiation_Diffuse_Tilted"].isnull()]
test_data.shape


x_test = test_data[["Diffuse_Horizontal_Radiation"]]
x_test.shape
# Out:
# (5496, 1)

# %%
train_data = df.dropna(subset="Radiation_Diffuse_Tilted")
train_data.shape

x_train = train_data[["Diffuse_Horizontal_Radiation"]]
x_train = x_train.fillna(method='ffill')
x_train.shape

y_train = train_data["Radiation_Diffuse_Tilted"]
y_train.shape
# Out:
# (54792,)

# %%
LR_model.fit(x_train, y_train)

train_score = LR_model.score(x_train, y_train)

print(f"Model Score (R^2) on Training Data: {train_score}")

from sklearn.metrics import mean_absolute_error
y_train_pred = LR_model.predict(x_train)
mae_train = mean_absolute_error(y_train, y_train_pred)

mse = mean_squared_error(y_train, y_train_pred)
rmse = math.sqrt(mse)
print(f'Root Mean Squared Error: {rmse}')

print(f"Mean Absolute Error (MAE) on Training Data: {mae_train}")
# Out:
# Model Score (R^2) on Training Data: 0.9693113713240658
# Root Mean Squared Error: 15.807552924582065
# Mean Absolute Error (MAE) on Training Data: 6.416397364593374

# %%
# Train the model
random_forest_model.fit(x_train, y_train)
train_score_rf = random_forest_model.score(x_train, y_train)

print(f"Model Score (R^2) on Training Data: {train_score_rf}")
from sklearn.metrics import mean_absolute_error
y_train_pred = random_forest_model.predict(x_train)
mae_train = mean_absolute_error(y_train, y_train_pred)

mse = mean_squared_error(y_train, y_train_pred)
rmse = math.sqrt(mse)
print(f'Root Mean Squared Error: {rmse}')

print(f"Mean Absolute Error (MAE) on Training Data: {mae_train}")
# Out:
# Model Score (R^2) on Training Data: 0.9873388009907296
# Root Mean Squared Error: 10.15344266801207
# Mean Absolute Error (MAE) on Training Data: 2.6466593992721825

# %%
predictions = random_forest_model.predict(x_test)

# %%
test_data.loc[test_data.Radiation_Diffuse_Tilted.isnull(), 'Radiation_Diffuse_Tilted'] = y_pred
test_data.head()
# Out:
#     Weather_Temperature_Celsius  Weather_Relative_Humidity  \
# 73                    14.947137                  36.891554
# 74                    14.157577                  41.880628
# 75                    13.462600                  45.648246
# 76                    12.623549                  48.682053
# 77                    12.252230                  50.790312
#
#     Global_Horizontal_Radiation  Diffuse_Horizontal_Radiation  Wind_Direction  \
# 73                     2.769133                      1.122296      243.446524
# 74                     2.890077                      1.223685      249.287980
# 75                     2.771298                      1.136136      238.922204
# 76                     2.890348                      1.239373       12.695471
# 77                     2.618698                      0.993133      258.034283
#
#     Weather_Daily_Rainfall  Radiation_Global_Tilted  Radiation_Diffuse_Tilted  \
# 73                     0.0                 2.229095                  2.229095
# 74                     0.0                 1.707711                  1.707711
# 75                     0.0                 2.506192                  2.506192
# 76                     0.0                 2.016426                  2.016426
# 77                     0.0                 2.618487                  2.618487
#
#                   date        Date  hour  month  year
# 73 2016-04-04 01:00:00  2016-04-04     1      4  2016
# 74 2016-04-04 02:00:00  2016-04-04     2      4  2016
# 75 2016-04-04 03:00:00  2016-04-04     3      4  2016
# 76 2016-04-04 04:00:00  2016-04-04     4      4  2016
# 77 2016-04-04 05:00:00  2016-04-04     5      4  2016

# %%
df = pd.concat([train_data,test_data])
df.sort_index(inplace=True)
df.head()
# Out:
#    Weather_Temperature_Celsius  Weather_Relative_Humidity  \
# 0                    15.695308                  40.470138
# 1                    15.458908                  38.914876
# 2                    15.686191                  38.183398
# 3                    14.938666                  42.768116
# 4                    13.401448                  51.339947
#
#    Global_Horizontal_Radiation  Diffuse_Horizontal_Radiation  Wind_Direction  \
# 0                     2.656972                      1.036526      246.619743
# 1                     2.409956                      0.803828       54.343306
# 2                     2.349933                      0.776835       68.148311
# 3                     3.003918                      1.336927      168.825974
# 4                     3.034377                      1.368935      228.932444
#
#    Weather_Daily_Rainfall  Radiation_Global_Tilted  Radiation_Diffuse_Tilted  \
# 0                     0.0                 3.082348                  1.688183
# 1                     0.0                 2.691869                  1.369937
# 2                     0.0                 2.676784                  1.350582
# 3                     0.0                 3.319331                  1.908877
# 4                     0.0                 3.422762                  2.012935
#
#                  date        Date  hour  month  year
# 0 2016-04-01 00:00:00  2016-04-01     0      4  2016
# 1 2016-04-01 01:00:00  2016-04-01     1      4  2016
# 2 2016-04-01 02:00:00  2016-04-01     2      4  2016
# 3 2016-04-01 03:00:00  2016-04-01     3      4  2016
# 4 2016-04-01 04:00:00  2016-04-01     4      4  2016

# %%
result = pd.concat([df, df1], axis=1)
result = pd.read_csv('combined_file.csv')
result.shape

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# Assuming 'data' is your DataFrame with features and target variable
# Separate features (X) and target variable (y)
#X = df.drop(columns=['Active_Power'])  # Features (input variables)
#y = data['target_column_name']  # Target variable (output variable)

# Normalize the features using MinMaxScaler
scaler = MinMaxScaler()
normalized = scaler.fit_transform(df)

pd.DataFrame(normalized).to_csv("normalized_data1.csv")
#normalized.to_csv('normalized_data.csv', index=False)

from google.colab import files
files.download('normalized_data1.csv')
